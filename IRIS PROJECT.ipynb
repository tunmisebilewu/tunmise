# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
import csv
import random
import math
import operator

# Handle Data
def load_dataset(filename, split_ratio):
    training_data = []
    test_data = []
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for i in range(len(dataset) - 1):
            for j in range(4):
                dataset[i][j] = float(dataset[i][j])
            if random.random() < split_ratio:
                training_data.append(dataset[i])
            else:
                test_data.append(dataset[i])
    return training_data, test_data

# Similarity
def euclidean_distance(instance1, instance2, length):
    distance = 0
    for i in range(length):
        distance += pow((instance1[i] - instance2[i]), 2)
    return math.sqrt(distance)

# Neighbors
def get_neighbors(training_data, test_instance, k):
    distances = []
    length = len(test_instance) - 1
    for i in range(len(training_data)):
        dist = euclidean_distance(test_instance, training_data[i], length)
        distances.append((training_data[i], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for i in range(k):
        neighbors.append(distances[i][0])
    return neighbors

# Response
def get_response(neighbors):
    class_votes = {}
    for neighbor in neighbors:
        response = neighbor[-1]
        if response in class_votes:
            class_votes[response] += 1
        else:
            class_votes[response] = 1
    sorted_votes = sorted(class_votes.items(), key=operator.itemgetter(1), reverse=True)
    return sorted_votes[0][0]

# Accuracy
def get_accuracy(test_data, predictions):
    correct = 0
    for i in range(len(test_data)):
        if test_data[i][-1] == predictions[i]:
            correct += 1
    return (correct / float(len(test_data))) * 100.0

# Main
def main():
    filename = 'iris.csv'
    split_ratio = 0.67
    training_data, test_data = load_dataset(filename, split_ratio)
    predictions = []
    k = 3
    for i in range(len(test_data)):
        neighbors = get_neighbors(training_data, test_data[i], k)
        result = get_response(neighbors)
        predictions.append(result)
        print(f'Actual: {test_data[i][-1]}, Predicted: {result}')
    accuracy = get_accuracy(test_data, predictions)
    print(f'Accuracy: {accuracy:.2f}%')

main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2760\1604257258.py in <module>
#      75     print(f'Accuracy: {accuracy:.2f}%')
#      76
# ---> 77 main()
#
# ~\AppData\Local\Temp\ipykernel_2760\1604257258.py in main()
#      64     filename = 'iris.csv'
#      65     split_ratio = 0.67
# ---> 66     training_data, test_data = load_dataset(filename, split_ratio)
#      67     predictions = []
#      68     k = 3
#
# ~\AppData\Local\Temp\ipykernel_2760\1604257258.py in load_dataset(filename, split_ratio)
#      13         for i in range(len(dataset) - 1):
#      14             for j in range(4):
# ---> 15                 dataset[i][j] = float(dataset[i][j])
#      16             if random.random() < split_ratio:
#      17                 training_data.append(dataset[i])
#
# ValueError: could not convert string to float: 'sepal.length'

# %%
import csv
import random
import math
import operator
# Handle Data
def load_dataset(filename, split_ratio):
    training_data = []
    test_data = []
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)[1:]  # Skip the first row (headers)
        for i in range(len(dataset) - 1):
            for j in range(4):
                dataset[i][j] = float(dataset[i][j])
            if random.random() < split_ratio:
                training_data.append(dataset[i])
            else:
                test_data.append(dataset[i])
    return training_data, test_data


# Similarity
def euclidean_distance(instance1, instance2, length):
    distance = 0
    for i in range(length):
        distance += pow((instance1[i] - instance2[i]), 2)
    return math.sqrt(distance)

# Neighbors
def get_neighbors(training_data, test_instance, k):
    distances = []
    length = len(test_instance) - 1
    for i in range(len(training_data)):
        dist = euclidean_distance(test_instance, training_data[i], length)
        distances.append((training_data[i], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for i in range(k):
        neighbors.append(distances[i][0])
    return neighbors

# Response
def get_response(neighbors):
    class_votes = {}
    for neighbor in neighbors:
        response = neighbor[-1]
        if response in class_votes:
            class_votes[response] += 1
        else:
            class_votes[response] = 1
    sorted_votes = sorted(class_votes.items(), key=operator.itemgetter(1), reverse=True)
    return sorted_votes[0][0]

# Accuracy
def get_accuracy(test_data, predictions):
    correct = 0
    for i in range(len(test_data)):
        if test_data[i][-1] == predictions[i]:
            correct += 1
    return (correct / float(len(test_data))) * 100.0

# Main
def main():
    filename = 'iris.csv'
    split_ratio = 0.67
    training_data, test_data = load_dataset(filename, split_ratio)
    predictions = []
    k = 3
    for i in range(len(test_data)):
        neighbors = get_neighbors(training_data, test_data[i], k)
        result = get_response(neighbors)
        predictions.append(result)
        print(f'Actual: {test_data[i][-1]}, Predicted: {result}')
    accuracy = get_accuracy(test_data, predictions)
    print(f'Accuracy: {accuracy:.2f}%')

main()
# Out:
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Setosa, Predicted: Setosa
# Actual: Versicolor, Predicted: Versicolor
# Actual: Versicolor, Predicted: Versicolor
# Actual: Versicolor, Predicted: Versicolor
# Actual: Versicolor, Predicted: Versicolor
# Actual: Versicolor, Predicted: Versicolor
# Actual: Versicolor, Predicted: Versicolor
# ...
